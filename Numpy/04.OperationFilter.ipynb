# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Operation And Filter</h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px">
#     <ul>
#     <li>
#     <a href="#arithmetic">Arithmetic</a>
#     </li>
#     <li>
#     <a href="#inFun">Arithmetic Functions</a>
#     </li>
#     <li>
#     <a href="#scalar">Scalar Oerations</a>
#     </li>
#     <li>
#     <a href="#comparison">Comparison</a>
#     </li>
#     <li>
#     <a href="#mask">Boolean Mask</a>
#     </li>
#     </ul>
# </div>
#
# <hr>

# %% [markdown]
# <div id="arithmetic">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline; font-weight: bold">Arithmetic</h3>
#
# <pre>
# `+`
# `-`
# `*`
# `/`
# `//`
# `%`
# </pre>
#
# </div>

# %% [markdown]
# <div id="inFun">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Airthmetic Functions</h3>
# </div>

# %% [markdown]
# <div id="scalar">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Scalar Oerations</h3>
# </div>

# %% [markdown]
# <div id="comparison">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Comparison</h3>
# </div>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved</i></h5>
# </div>
