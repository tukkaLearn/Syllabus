# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Math Function</h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px">
#     <ul>
#     <li>
#     <a href="#math">Math</a>
#     </li>
#     </ul>
# </div>
#
# <hr>

# %% [markdown]
# <div id="math">
# <h3 style="text-align:center; color:skyblue ; text-decoration: underline ;font-weight: bold">Math</h3>
# </div>
#
# <div>
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
#
# <li>
# <abbr title="Add Value to Array">add</abbr>
# </li>
# <li>
# <abbr title="Subtract Value from Array">subtract</abbr>
# </li>
# <li>
# <abbr title="Multiply Value to Array">multiply</abbr>
# </li>
# <li>
# <abbr title="Divide Value from Array">divide</abbr>
# </li>
# <li>
# <abbr title="Exponential">exp</abbr>
# </li>
# <li>
# <abbr title="Log value with base e">log</abbr>
# </li>
# <li>
# <abbr title="Log value with base 10">log10</abbr>
# </li>
# <li>
# <abbr title="Square Root">sqrt</abbr>
# </li>
# <li>
# <abbr title="Power">power</abbr>
# </li>
# <li>
# <abbr title="deg to rad">deg2rad</abbr>
# </li>
# <li>
# <abbr title="absolute">abs</abbr>
# </li>
# <li>
# <abbr title="round a number to nearest integer or pass value">round</abbr>
# </li>
# <li>
# <abbr title="round a number to nearest lower integer">floor</abbr>
# </li>
# <li>
# <abbr title="round a number to nearest higher integer">ceil</abbr>
# </li>
# <li>
# <abbr title="Returns True if any element of the array is True">any</abbr>
# </li>
# <li>
# <abbr title="Returns True if all elements of the array are True">all</abbr>
# </li>
# </ol>
# </div>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved</i></h5>
# </div>
