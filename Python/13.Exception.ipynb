# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Exception Handling
# </h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px ">
#     <ul style="display: flex; flex-direction: column; gap: 10px">
#     <li>
#     <a href="#exception">Exception Handling</a>
#     </li>
#     <li>
#     <a href="#custom">Custom Exceptions</a>
#     </li>
#
# </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# <div id="exception">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Exception</h3>
#
# <p>An exception is an error that occurs during the execution of code. This error causes the code to raise an exception and if not prepared to handle it will halt the execution of the code.
# </p>
#
# <code>try ... except ...</code>
#
# <code>try ... except ... except ...</code>
#
# <code>try ... except ... else ...</code>
#
# <code>try ... except ... finally ...</code>
#
# </div>

# %% [markdown]
# <div id="custom">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Custom Exceptions</h3>
#
# </div>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved </i></h5>
# </div>
