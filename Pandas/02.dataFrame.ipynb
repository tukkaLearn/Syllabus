# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">DataFrame</h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px">
#     <ul>
#     <li>
#     <a href="">DataF Creation</a>
#     </li>
#     <li>
#     <a href="">Concat Data</a>
#     </li>
#     <li>
#     <a href="">Read CSV</a>
#     </li>
#     <li>
#     <a href="">Chunk</a>
#     </li>
#     <li>
#     <a href="">Save Data</a>
#     </li>
#     </ul>
# </div>
# <hr>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Data Creation</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Concat Data</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Read CSV</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Chunk</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Save Data</h3>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
# </div>
