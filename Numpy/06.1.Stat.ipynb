# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Statistical Functions</h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px">
#     <ul>
#     <li>
#     <a href="#statistical">Statistical</a>
#     </li>
#     </ul>
# </div>
#
# <hr>

# %% [markdown]
# <div id="statistical">
# <h3 style="text-align:center; color:skyblue ; text-decoration: underline ;font-weight: bold">Statistical</h3>
# </div>
#
# <div>
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
# <li>
# <abbr title="Returns the minimum along a given axis.">min</abbr>
# </li>
# <li>
# <abbr title="Returns the maximum along a given axis.">max</abbr>
# </li>
# <li>
# <abbr title="Returns the min value index along a given axis.">argmin</abbr>
# </li>
# <li>
# <abbr title="Returns the maximum value index along a given axis.">argmin</abbr>
# </li>
# <li>
# <abbr title="Returns the mean along a given axis.">mean</abbr>
# </li>
# <li>
# <abbr title="Returns the median along a given axis.">median</abbr>
# </li>
# <li>
# <abbr title="Returns the average but weight the data by its standard deviation.">average</abbr>
# </li>
# <li>
# <abbr title="Returns the variance along a given axis.">var</abbr>
# </li>
# <li>
# <abbr title="Returns the standard deviation along a given axis.">std</abbr>
# </li>
# <li>
# <abbr title="percentile">percentile</abbr>
# </li>
# <li>
# <abbr title="quantile pass value between 0 to 1">quantile</abbr>
# </li>
# <li>
# <abbr title="range">range</abbr>
# </li>
# <li>
# <abbr title="correlation">corrcoef</abbr>
# </li>
# <li>
# <abbr title="covariance">cov</abbr>
# </li>
# <li>
# <abbr title="percentile">Cumulative Sum</abbr>
# </li>
# <li>
# <abbr title="percentile">Cumulative Product</abbr>
# </li>
# </ol>
# </div>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved</i></h5>
# </div>
