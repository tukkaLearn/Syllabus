# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Module
# </h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px ">
#     <ul style="display: flex; flex-direction: column; gap: 10px">
#     <li>
#     <a href="#module">Module</a>
#     </li>
#
# </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# <div id="pre">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">In-Built Module</h3>
#
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
# <li><a href="#math"><abbr title="Provides mathematical functions like sqrt, pow, log, sin etc.">math</abbr></a></li>
# <li><a href="#time"><abbr title="Handles time-related functions like sleep(), time(), perf_counter()">time</abbr></a></li>
# <li><a href="#datetime"><abbr title="Handles date and time operations like datetime.now(), timedelta()">datetime</abbr></a></li>
# <li><a href="#random"><abbr title="Used for generating random numbers or choices">random</abbr></a></li>
# <li><a href="#os"><abbr title="Used to interact with the operating system (files, paths, environment)">os</abbr></a></li>
# <li><a href="#glob"><abbr title="Used to find file names matching a specific pattern (like *.csv)">glob</abbr></a></li>
# <li><a href="#argparse"><abbr title="Handles command-line arguments and flags in CLI programs">argparse</abbr></a></li>
# <li><a href="#re"><abbr title="Provides support for regular expressions like pattern matching, validation">re</abbr></a></li>
# <li><a href="#collections"><abbr title="Provides data structures like Counter, defaultdict, deque, namedtuple">collections</abbr></a></li>
# <li><a href="#itertools"><abbr title="Helps in building efficient iterators, infinite sequences, combinatorics">itertools</abbr></a></li>
# <li><a href="#statistics"><abbr title="Provides statistical functions like mean(), median(), stdev()">statistics</abbr></a></li>
# <li><a href="#typing"><abbr title="Used to give hints about variable types and function signatures">typing</abbr></a></li>
# <li><a href="#csv"><abbr title="Used to read, write, and process CSV (Comma Separated Values) files">csv</abbr></a></li>
# <li><a href="#json"><abbr title="Used to read/write JSON data (useful for APIs and config)">json</abbr></a></li>
#
# </ol>
#
# </div>

# %% [markdown]
# <div id="random">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">random</h3>
#
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
# <li><abbr title="Returns a random float number between 0.0 to 1.0">random.random()</abbr></li>
# <li><abbr title="Returns a random float between two values (inclusive)">random.uniform(a, b)</abbr></li>
# <li><abbr title="Returns a random integer between two values (inclusive)">random.randint(a, b)</abbr></li>
# <li><abbr title="Returns a random element from a non-empty sequence">random.choice(sequence)</abbr></li>
# <li><abbr title="Shuffles the sequence in place (no return value)">random.shuffle(list)</abbr></li>
# <li><abbr title="Returns a random element from range(start, stop[, step])">random.randrange(start, stop[, step])</abbr></li>
# <li><abbr title="Seeds the random generator (for reproducibility)">random.seed(value)</abbr></li>
#
# </ol>
#
# </div>

# %% [markdown]
# <div id="os">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">os</h3>
#
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
# <li><abbr title="Returns the current working directory">os.getcwd()</abbr></li>
# <li><abbr title="Changes the current working directory">os.chdir(path)</abbr></li>
# <li><abbr title="Lists all files and directories in the given path">os.listdir(path)</abbr></li>
# <li><abbr title="Creates a new directory">os.mkdir(path)</abbr></li>
# <li><abbr title="Creates intermediate directories as needed">os.makedirs(path)</abbr></li>
# <li><abbr title="Removes a file">os.remove(file)</abbr></li>
# <li><abbr title="Removes an empty directory">os.rmdir(path)</abbr></li>
# <li><abbr title="Removes directory tree (non-empty dirs)">os.removedirs(path)</abbr></li>
# <li><abbr title="Renames a file or directory">os.rename(old, new)</abbr></li>
# <li><abbr title="Checks if the given path is a file">os.path.isfile(path)</abbr></li>
# <li><abbr title="Checks if the given path is a directory">os.path.isdir(path)</abbr></li>
# <li><abbr title="Joins two or more parts of a file path">os.path.join(path1, path2)</abbr></li>
# <li><abbr title="base name of file">os.path.basename(filename)</abbr></li>
# <li><abbr title="Returns the absolute version of a path">os.path.abspath(path)</abbr></li>
# <li><abbr title="Splits path into head and tail">os.path.split(path)</abbr></li>
# <li><abbr title="Splits path into root and extension">os.path.splitext(path)</abbr></li>
# <li><abbr title="Returns environment variables as a dictionary">os.environ</abbr></li>
#
# </ol>
#
# </div>

# %% [markdown]
# <div id="shutil">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">shutil</h3>
#
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
#   <li><abbr title="Copies a file from source to destination">shutil.copy(src, dst)</abbr></li>
#   <li><abbr title="Copies a file along with its metadata (permissions, modification times)">shutil.copy2(src, dst)</abbr></li>
#   <li><abbr title="Copies an entire directory tree from source to destination">shutil.copytree(src, dst)</abbr></li>
#   <li><abbr title="Moves a file or directory to another location">shutil.move(src, dst)</abbr></li>
#   <li><abbr title="Removes an entire directory tree">shutil.rmtree(path)</abbr></li>
#   <li><abbr title="Creates an archive file (e.g., zip or tar) from a directory">shutil.make_archive(base_name, format, root_dir)</abbr></li>
#   <li><abbr title="Unpacks an archive file (e.g., zip or tar) to a directory">shutil.unpack_archive(filename, extract_dir)</abbr></li>
#   <li><abbr title="Returns disk usage statistics about the given path">shutil.disk_usage(path)</abbr></li>
# </ol>

# %% [markdown]
# <div id="glob">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">glob</h3>
#
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
# <li><abbr title="Returns a list of file paths matching a pattern">glob.glob('*.csv')</abbr></li>
# <li><abbr title="Returns all matching files in current and subdirectories">glob.glob('**/*.txt', recursive=True)</abbr></li>
# <li><abbr title="Finds files using wildcard * and ?">glob.glob('data?.csv')</abbr></li>
# <li><abbr title="Returns an iterator instead of list for large results">glob.iglob('*.py')</abbr></li>
#
# </ol>
#
# </div>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Uploading System</h3>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved</i></h5>
# </div>
