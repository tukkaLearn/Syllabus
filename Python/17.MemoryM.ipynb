# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Memory Management
# </h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px ">
#     <ul style="display: flex; flex-direction: column; gap: 10px">
#     <li>
#     <a href="#multithreading">Multithreading</a>
#     </li>
#     <li>
#     <a href="#multiprocessing">MultiProcessing</a>
#     </li>
#
# </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# <div id="multithreading">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Multithreading</h3>
#
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
#
# <li><abbr title="Creates a new thread with target function">threading.Thread(target=function)</abbr></li>
# <li><abbr title="Starts the thread execution">thread.start()</abbr></li>
# <li><abbr title="Waits for the thread to finish">thread.join()</abbr></li>
# <li><abbr title="Returns the name of the current thread">threading.current_thread().name</abbr></li>
# <li><abbr title="Checks if thread is still running">thread.is_alive()</abbr></li>
# <li><abbr title="Locks shared resources to avoid conflict">threading.Lock()</abbr></li>
#
# </ol>
#
# </div>

# %% [markdown]
# <div id="multiprocessing">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">MultiProcessing</h3>
# <!--
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
# <li><abbr title="Creates a separate process">multiprocessing.Process(target=function)</abbr></li>
# <li><abbr title="Starts a new process">process.start()</abbr></li>
# <li><abbr title="Waits for the process to finish">process.join()</abbr></li>
# <li><abbr title="Manages a pool of worker processes">multiprocessing.Pool()</abbr></li>
# <li><abbr title="Applies a function to multiple inputs in parallel">pool.map(func, iterable)</abbr></li>
# <li><abbr title="Used to share data between processes">multiprocessing.Queue()</abbr></li>
# <li><abbr title="Synchronize access to shared resources">multiprocessing.Lock()</abbr></li>
# <li><abbr title="Returns current process object">multiprocessing.current_process()</abbr></li>
# </ol> -->
#
# </div>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved</i></h5>
# </div>
