# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Data Modification And Filtering</h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px">
#     <ul>
#     <li>
#     <a href="">Modify using loc</a>
#     </li>
#     <li>
#     <a href="">Modify using iloc</a>
#     </li>
#     <li>
#     <a href="">replace</a>
#     </li>
#     <li>
#     <a href="">Filter Using Mask</a>
#     </li>
#     <li>
#     <a href="">Filter Using Where</a>
#     </li>
#     <li>
#     <a href="">Filter Using Between</a>
#     </li>
#     <li>
#     <a href="">Insert</a>
#     </li>
#     <li>
#     <a href="">Rename</a>
#     </li>
#     <li>
#     <a href="">Set Index</a>
#     </li>
#     <li>
#     <a href="">Reset Index</a>
#     </li>
#     </ul>
# </div>
#
# <hr>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Modify using loc and iloc</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Replace</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Filter Using Mask</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Filter Using Where</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Insert</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Rename</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Set index</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Reset Index</h3>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
# </div>
