# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Control Flow Statement
# </h2>
#
# <div style="display:flex ; justify-content: center">
# <img src=https://pynative.com/wp-content/uploads/2021/03/python-flow-control-statements.png">
#
# </div>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px ">
#     <ul style="display: flex; flex-direction: column; gap: 10px">
#     <li>
#     <a href="#control">Conditional Statement</a>
#     </li>
#     <li>
#     <a href="#loop">
#     Loop</a>
#     </li>
#     <li>
#     <a href="#transfer">Transfer</a>
#     </li>
#
#
# </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# <div id="loop">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Loop</h3>
#
# <div style="display:flex ; justify-content: center">
# <img src="https://media2.giphy.com/media/v1.Y2lkPTZjMDliOTUyYnA4emlvd3VrMWh0NTQxMzgwY3V2d3B5amtiN2pqaGJlYzN0MjZtYSZlcD12MV9naWZzX3NlYXJjaCZjdD1n/YAlhwn67KT76E/giphy.gif">
#
# </div>
# <p>Perform Operation On Loop</p>
#
# <h5>Types of Loop</h4>
# <ul style="display: flex; flex-direction: column; gap: 10px;font-size: 18px">
#     <li> <a href="#while"> <code>while</code></a></li>
#     <li> <a href="#nwhile"> <code>nested while</code></a></li>
#     <li> <a href="#for"> <code>for</code></a></li>
#     <li> <a href="#nfor"> <code>nested for</code></a></li>
# </ul>
#
# </div>

# %% [markdown]
# <div id="while">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">while</h3>
# <p>Loop Must make a Termination Point Otherwise It run ...</p>
# <br/>
# <div style="display:flex ; justify-content: center">
# <img src="https://mir-s3-cdn-cf.behance.net/project_modules/disp/3edc1930542077.5627ab91db937.gif" width="200">
#
# </div>
#
# </div>

# %% [markdown]
# <div style="display:flex ; justify-content: center">
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/LoopsWhile.gif" width="650">
#
# </div>

# %% [markdown]
# <div id="nwhile" >
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Nested while Loop</h3>
# <p>Loop inside Loop ...</p>
# <br/>
#
# </div>

# %% [markdown]
# <div id="for" >
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">for</h3>
# <br/>
# </div>

# %% [markdown]
# <div style="display:flex ; justify-content: center">
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/LoopsForRange.gif" width="600">
#
# </div>

# %% [markdown]
# <div id="nfor" >
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">nested for</h3>
# <br/>
# </div>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved</i></h5>
# </div>
