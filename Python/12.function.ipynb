# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Function
# </h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px ">
#     <ul style="display: flex; flex-direction: column; gap: 10px">
#     <li>
#     <a href="#types">Types Of Function</a>
#     </li>
#     <li>
#     <a href="#legb">LEGB Rules</a>
#     </li>
#
# </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# <div id="types">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Types Of Function</h3>
#
# <p>We have two types of function.</p>
#
# <div style="margin-top: 20px ">
#     <ul style="display: flex; flex-direction: column; gap: 10px">
#     <li>
#     <a href="#userDefine">User Define Function</a>
#     </li>
#     <li>
#     <a href="#preDefine">Pre Define Function</a>
#     </li>
# </ul>
#
# </div>

# %% [markdown]
# <div id="userDefine">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">User Define Function</h3>
#
# Simple rules to define a function in Python:
#
# - Functions blocks begin <code>def</code> followed by the function <code>name</code> and parentheses <code>()</code>.
# - There are input parameters or arguments that should be placed within these parentheses.
# - You can also define parameters inside these parentheses.
# - There is a body within every function that starts with a colon (<code>:</code>) and is indented.
# - You can also place documentation before the body.
# - The statement <code>return</code> exits a function, optionally passing back a value.
#   <br>
#
# <div style="margin-top: 20px ">
# <code>Different Types of User Define Function</code>
#     <ol style="display: flex; flex-direction: column; gap: 10px">
#     <li>
#     <a href="#nonParameter">Non Parametrizes</a>
#     </li>
#     <li>
#     <a href="#parametrize">Parametrizes</a>
#     </li>
#     <li>
#     <a href="#defaultParameter">Default Parameter</a>
#     </li>
#     <li>
#     <a href="#positional">Positional Argument</a>
#     </li>
#     <li>
#     <a href="#args">Variable Length Arguments</a>
#     </li>
#     <li>
#     <a href="#kwargs">keyword arguments</a>
#     </li>
#     <li>
#     <a href="#return">Return</a>
#     </li>
#     <li>
#     <a href="#recursion">Recursion</a>
#     </li>
#     <li>
#     <a href="#anon">Anonymous</a>
#     </li>
#     <li>
#     <a href="#closure">Closure Function</a>
#     </li>
#     <li>
#     <a href="#decorator">Decorator Function</a>
#     </li>
#     <li>
#     <a href="#generator">Generator</a>
#     </li>
#     <li>
#     <a href="#higher">Higher Order Function</a>
#     </li>
#
# </ol>
#
# </div>

# %% [markdown]
# <div id="nonParameter">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Non Parametrizes Function</h3>
#
# </div>

# %% [markdown]
# <div id="parametrize">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Parametrizes Function</h3>
#
# <div style="display:flex ; justify-content: center">
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/FuncsDefinition.png" width="500">
# </div>
#
# </div>

# %% [markdown]
# <div id="defaultParameter">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Default Parameter Function</h3>
#
# </div>

# %% [markdown]
# <div id="positional">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Positional Argument Function</h3>
#
# </div>

# %% [markdown]
# <div id="args">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Variable Length Arguments Function</h3>
#
# </div>

# %% [markdown]
# <div id="kwargs">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Keyword Argument Function</h3>
#
# </div>

# %% [markdown]
# <div id="return">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Return Function</h3>
#
# </div>

# %% [markdown]
# <div id="nested">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Nested Function</h3>
#
# </div>

# %% [markdown]
# <div id="Recursion">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Recursion Function</h3>
#
# </div>

# %% [markdown]
# <div id="anon">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Anonymous (lambda) Function</h3>
#
# </div>

# %% [markdown]
# <div id="generator">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Generator (yield) Function</h3>
#
# <p>Returns a value from a generator and pauses the function state</p>
# </div>

# %% [markdown]
# <div id="higher">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Higher Order Function</h3>
#
# <p>A function that takes another function as an argument, or returns a function as output — is called a Higher-Order Function (HOF)</p>
#
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
#
# <li>
# <abbr title="Applies a function to each item in list">map()  </abbr>
# </li>
# <li>
# <abbr title="Filters items using a condition">filter()  </abbr>
# </li>
# <li>
# <abbr title="Reduces list to single value">reduce()  </abbr>
# </li>
# <li>
# <abbr title="Custom sorting function">sorted() with key</abbr>
# </li>
#
# </ol>
#
# </div>

# %% [markdown]
# <div id="preDefine">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Pre Define Function</h3>
#
# <p>Function which is pre defined in python also called as built-in function</p>
#
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
#
# <li><abbr title="Prints output to the console">print()</abbr></li>
# <li><abbr title="Takes input from the user">input()</abbr></li>
# <li><abbr title="Returns the number of items in an object">len()</abbr></li>
# <li><abbr title="Returns the type of object">type()</abbr></li>
# <li><abbr title="Converts a value to integer">int()</abbr></li>
# <li><abbr title="Converts a value to float">float()</abbr></li>
# <li><abbr title="Converts a value to string">str()</abbr></li>
# <li><abbr title="Converts a value to list">list()</abbr></li>
# <li><abbr title="Creates a dictionary">dict()</abbr></li>
# <li><abbr title="Returns an iterator">iter()</abbr></li>
# <li><abbr title="Returns the next item in an iterator">next()</abbr></li>
# <li><abbr title="Returns the sum of all items in an iterable">sum()</abbr></li>
# <li><abbr title="Returns the largest item">max()</abbr></li>
# <li><abbr title="Returns the smallest item">min()</abbr></li>
# <li><abbr title="Returns a sorted list">sorted()</abbr></li>
# <li><abbr title="Reverses the given iterable">reversed()</abbr></li>
# <li><abbr title="Enumerates items with index">enumerate()</abbr></li>
# <li><abbr title="Combines two or more iterables">zip()</abbr></li>
# <li><abbr title="Applies a function to each item in iterable">map()</abbr></li>
# <li><abbr title="Filters items using a condition">filter()</abbr></li>
# <li><abbr title="Returns True if all items are true">all()</abbr></li>
# <li><abbr title="Returns True if any item is true">any()</abbr></li>
# <li><abbr title="Generates a sequence of numbers">range()</abbr></li>
# <li><abbr title="Returns the absolute value">abs()</abbr></li>
# <li><abbr title="Rounds off a number">round()</abbr></li>
# <li><abbr title="Evaluates a string as Python expression">eval()</abbr></li>
# <li><abbr title="Returns memory address of an object">id()</abbr></li>
# <li><abbr title="Returns character for ASCII value">chr()</abbr></li>
# <li><abbr title="Returns ASCII for a character">ord()</abbr></li>
# <li><abbr title="Shows help/documentation">help()</abbr></li>
# <li><abbr title="Lists all functions and variables in the module.">dir()</abbr></li>
#
# </ol>
#
# </div>

# %% [markdown]
# <div id="legb">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">LEGB Rules</h3>
#
# <p>Define the rules for variable from which they are associated</p>
#
# <code>L : Local</code><br>
# <code>E : Enclosing</code><br>
# <code>G : Global</code><br>
# <code>B : Built-in</code>
#
# </div>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved </i></h5>
# </div>
