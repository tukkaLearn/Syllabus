# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Class
# </h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px ">
#     <ul style="display: flex; flex-direction: column; gap: 10px">
#     <li>
#     <a href="#class">Class</a>
#     </li>
#     <li>
#     <a href="#constructor">Constructor</a>
#     </li>
#     <li>
#     <a href="#classvariable">Class Variable</a>
#     </li>
#     <li>
#     <a href="#classmethod">Class Method</a>
#     </li>
#     <li>
#     <a href="#staticmethod">Static Method</a>
#     </li>
#     <li>
#     <a href="#encapsulation">Encapsulation</a>
#     </li>
#     <li>
#     <a href="#abstraction">Abstraction</a>
#     </li>
#     <li>
#     <a href="#specifier">Access Specifier</a>
#     </li>
#     <li>
#     <a href="#setter">Setter, Getter Decorators</a>
#     </li>
#     <li>
#     <a href="#inheritance">Inheritance</a>
#     </li>
#     <li>
#     <a href="#overriding">Overriding</a>
#     </li>
#     <li>
#     <a href="#dunder">Dunder</a>
#     </li>
#     <li>
#     <a href="#overloading">operator overloading</a>
#     </li>
#     <li>
#     <a href="#polymorphism">Polymorphism</a>
#     </li>
#
# </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# <div id="class">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Class</h3>
#
# <div style="display:flex ; justify-content: center">
# <img src="
# https://codersite.dev/assets/images/carClass.jpg
# " width="600">
#
# </div>
#
# <br>
# <br>
#
# </div>

# %% [markdown]
# <div style="display:flex ; justify-content: center">
# <img src="
# https://www.parthpatel.net/static/569b251a823d8e1fd08daf059a988f9c/10fd8/class-and-objects-php.jpg
# " width="500">
#
# </div>

# %% [markdown]
# <div id="constructor">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Constructor</h3>
# <p>A constructor is a special method that is called when an object is created from a class.</p>
#
# </div>

# %% [markdown]
# <p>Blue print</p>
# <div style="display:flex ; justify-content: center">
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/ClassesClass.png" width="500" >
# </div>

# %% [markdown]
# <p>Object</p>
# <div style="display:flex ; justify-content: center">
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/ClassesObj.png" width="500">
#
# </div>

# %% [markdown]
# <p>Method</p>
# <div style="display:flex ; justify-content: center">
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/ClassesMethod.png" width="500">
#
# </div>

# %% [markdown]
# <div id="classvariable">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Class Variable</h3>
#
# </div>

# %% [markdown]
# <div id="classmethod">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Class Method</h3>
#
# </div>

# %% [markdown]
# <div id="staticmethod">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Static Method</h3>
#
# </div>

# %% [markdown]
# <div id="dunder">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Dunder/Magic Method</h3>
#
# </div>

# %%
# # __dunder/magic___
#  __init__
#  __str__
# __len__
# __add__

# %% [markdown]
# <div id="specifier">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Access Specifier</h3>
#
# </div>

# %% [markdown]
# <div id="setter">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Setter, Getter Decorators</h3>
#
# </div>

# %% [markdown]
# <div id="encapsulation">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Encapsulation</h3>
#
# </div>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Single Level</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">MultiLevel</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Multiple </h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Hierarchical </h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">super keyword </h3>

# %% [markdown]
# <div id="polymorphism">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Polymorphism</h3>
#
# Method Overriding
#
# <code>Arithmetic Operator Overloading</code>
#
# <code>Relational Operator Overloading</code>
#
# <code>Logical Operator Overloading</code>
#
# </div>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Method Overriding</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Operator Overloading</h3>

# %% [markdown]
# <div id="abstraction">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Abstraction</h3>
#
# </div>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved</i></h5>
# </div>
