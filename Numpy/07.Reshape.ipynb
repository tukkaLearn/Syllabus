# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center"> Reshape</h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px">
#     <ul>
#     <li>
#     <a href="#reshape">Reshape</a>
#     </li>
#     <li>
#     <a href="#stack">Stacking</a>
#     </li>
#     <li>
#     <a href="#split">Split</a>
#     </li>
#     </ul>
# </div>
#
# <hr>

# %% [markdown]
# <div id="reshape">
# <h3 style="text-align:center; color:skyblue ; text-decoration: underline ;font-weight: bold">Reshape</h3>
# </div>
#
# <div>
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
#
# <li>
# <abbr title="Reshapes an array.">reshape</abbr>
# </li>
# <li>
# <abbr title="original affect.">ravel</abbr>
# </li>
# <li>
# <abbr title="original safely.">flatten</abbr>
# </li>
# <li>
# <abbr title="Transpose an array.">Transpose</abbr>
# </li>
# </ol>
# </div>

# %% [markdown]
# <div id="stack">
# <h3 style="text-align:center; color:skyblue ; text-decoration: underline ;font-weight: bold">Stack</h3>
# </div>
#
# <div>
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
# <li>
# <abbr title=" along existing axis">concatenate</abbr>
# </li>
# <li>
# <abbr title=" Vertical stack">vstack</abbr>
# </li>
# <li>
# <abbr title="Horizontal stack">hstack</abbr>
# </li>
# <li>
# <abbr title="3d stack">dstack</abbr>
# </li>
# <li>
# <abbr title="into N equal parts">split</abbr>
# </li>
# <li>
# <abbr title="split columns">hsplit</abbr>
# </li>
# <li>
# <abbr title="split rows">vsplit</abbr>
# </li>
# </ol>
# </div>

# %% [markdown]
# <div id="split">
# <h3 style="text-align:center; color:skyblue ; text-decoration: underline ;font-weight: bold">Splitting</h3>
# </div>
#
# <div>
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
# <li>
# <abbr title="into N equal parts">split</abbr>
# </li>
# <li>
# <abbr title="split columns">hsplit</abbr>
# </li>
# <li>
# <abbr title="split rows">vsplit</abbr>
# </li>
# </ol>
# </div>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved</i></h5>
# </div>
