# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Built-in Array Creation</h2>
#
# <h3>Table of Contents</h3>
# <div>
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
#
# <li>
# <abbr title="Returns a new array of given shape and type, filled with zeros">zeros()</abbr>
# </li>
# <li>
#     <abbr title="Returns a new array of given shape and type, filled with ones">ones()</abbr>
# </li>
#  <li>
#     <abbr title="Creates an array filled with a constant value."> full()</abbr>
# </li>
# <li>
#     <abbr title="Similar to Python’s range() but returns a NumPy array.">arange()</abbr>
# </li>
# <li>
#     <abbr title="Returns evenly spaced values over a specified interval">linspace()</abbr>
# </li>
# <li>
#     <abbr title="Creates a new identity array">identity()</abbr>
# </li>
# <li>
#     <abbr title="Returns a 2-D array with ones on the diagonal and zeros elsewhere">eye()</abbr>
# </li>
# <li>
#     <abbr title="Returns a garbage collection array">empty()</abbr>
# </li>
# <li>
# <a href="#random">Random</a>
# </li>
# </ol>
# </div>
#
# <hr>

# %% [markdown]
# <div id="random">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Random</h3>
# </div>
# <div>
# <ol style="color:#0fb3ff ; display:flex ; flex-direction: column ; gap:15px">
#
# <li>
# <abbr title="Returns a random number between 0.0 and 1.0">rand()</abbr>
# </li>
# <li>
#     <abbr title="Returns a sample (or samples) from the “standard normal” distribution">randn()</abbr>
# </li>
#   <li>
#     <abbr title="Radom integer value">randint()</abbr>
#     </li>
#     <li>
#     <abbr title="Random Choice">choice()</abbr>
#     </li>
#     <li>
#     <abbr title="shuffle Array">shuffle</abbr>
#     </li>
#     <li>
#     <abbr title="Random Permutation of an Array,it does not modify the original array.">permutation()</abbr>
#     </li>
#     <li>
#     <abbr title="Sets the seed for the random number generator.">seed()</abbr>
#     </li>
#
# </ol>
# </div>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved</i></h5>
# </div>
