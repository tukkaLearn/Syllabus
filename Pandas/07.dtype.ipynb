# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Data Types</h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px">
#     <ul>
#     <li>
#     <a href="">Number</a>
#     </li>
#     <li>
#     <a href="">String</a>
#     </li>
#     <li>
#     <a href="">Boolean</a>
#     </li>
#     <li>
#     <a href="">Category</a>
#     </li>
#     </ul>
# </div>
#
# <hr>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Number</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">String</h3>
#
# - str.upper()
# - str.lower()
# - str.split()
# - str.contains()
# - str.replace()
# - str.len()
# - str.strip()

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Boolean</h3>

# %% [markdown]
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Category</h3>
#
# - cat.categories
# - cat.codes
# - cat.add_categories()
# - cat.rename_categories()
# - cat.reorder_categories()

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
# </div>
