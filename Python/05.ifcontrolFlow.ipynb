# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Control Flow Statement
# </h2>
#
# <div style="display:flex ; justify-content: center">
# <img src=https://pynative.com/wp-content/uploads/2021/03/python-flow-control-statements.png">
#
# </div>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px ">
#     <ul style="display: flex; flex-direction: column; gap: 10px">
#     <li>
#     <a href="#control">Conditional Statement</a>
#     </li>
#     <li>
#     <a href="#loop">
#     Loop</a>
#     </li>
#     <li>
#     <a href="#transfer">Transfer</a>
#     </li>
#     <li>
#
# </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# <div id="control">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Conditional Statement</h3>
#
# <p>Perform Operation Based On Condition </p>
#
# <h5>Types of Conditional Statement</h4>
# <ul style="display: flex; flex-direction: column; gap: 10px;font-size: 18px">
#     <li> <a href="#if"> <code>if</code></a></li>
#     <li> <a href="#ifelse"><code>if else</code></a></li>
#     <li> <a href="#elif"><code>if-elif</code></a></li>
#     <li> <a href="#nested"><code>nested</code></a></li>
#     <li> <a href="#match"><code>match</code></a></li>
# </ul>
#
# </div>

# %% [markdown]
# <div id="if">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">if </h3>
#
# <br/>
# <div style="display:flex ; justify-content: center">
# <img src="https://pythonexamples.org/wp-content/uploads/2020/07/python-if.gif" width="600">
#
# </div>
#
# </div>

# %% [markdown]
# <div style="display:flex ; justify-content: center">
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/CondsIf.gif" width="450">
# </div>

# %% [markdown]
# <div id="ifelse">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">if-else </h3>
#
# <br/>
# <div style="display:flex ; justify-content: center">
# <img src="https://www.codingem.com/wp-content/uploads/2022/10/if-else-flowchart.png" width="800">
#
# </div>
#
# </div>

# %% [markdown]
# <div style="display:flex ; justify-content: center">
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/CondsLogicMap.png" width="450">
# </div>

# %% [markdown]
# <div id="elif">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">if-elif </h3>
#
# <br/>
# <div style="display:flex ; justify-content: center">
# <img src="https://www.scientecheasy.com/wp-content/uploads/2022/10/flowchart-if-elif-else.png" width="800">
#
# </div>
#
# </div>

# %% [markdown]
# <div id="nested">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">nested if else </h3>
#
# <br/>
#
# </div>

# %% [markdown]
# <div id="match">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">match </h3>
#
# <br/>
#
# </div>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved</i></h5>
# </div>
