# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Module
# </h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px ">
#     <ul style="display: flex; flex-direction: column; gap: 10px">
#     <li>
#     <a href="#module">Module</a>
#     </li>
#
# </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# <div id="module">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Module</h3>
#
# <p>A module is a file containing Python definitions and statements,It is use to group related functions and use it in another program</p>
#
# <div style="margin-top: 20px ">
# <code>Different Types of Modules</code>
#     <ol style="display: flex; flex-direction: column; gap: 10px">
#     <li>
#     <a href="#user">User Define Module </a>
#     </li>
#     <li>
#     <a href="#pre">In-Built Module </a>
#     </li>
#     <li>
#     <a href="#external">External Module </a>
#     </li>
#
# </ol>
#
# </div>

# %% [markdown]
# <div id="user">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">User Define Module</h3>
#
# <code>Full Module Import</code>
#
# <code>Specific Import</code>
#
# <code>Alias Import</code>
#
# </div>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved </i></h5>
# </div>
