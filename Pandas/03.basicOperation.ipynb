# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Basic Operation</h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px">
#     <ul>
#     <li>
#     <a href="">head</a>
#     </li>
#     <li>
#     <a href="">tail</a>
#     </li>
#     <li>
#     <a href="">columns</a>
#     </li>
#     <li>
#     <a href="">index</a>
#     </li>
#     <li>
#     <a href="">shape</a>
#     </li>
#     <li>
#     <a href="">dtypes</a>
#     </li>
#     <li>
#     <a href="">info</a>
#     </li>
#     <li>
#     <a href="">describe</a>
#     </li>
#     <li>
#     <a href="">value_counts</a>
#     </li>
#     <li>
#     <a href="">unique</a>
#     </li>
#     <li>
#     <a href="">nunique</a>
#     </li>
#     <li>
#     <a href="">max</a>
#     </li>
#     <li>
#     <a href="">min</a>
#     </li>
#     </ul>
# </div>
#
# <hr>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
# </div>
