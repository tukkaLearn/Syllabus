# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Vector</h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px">
#     <ul>
#     <li>
#     <a href="#vector">Vector</a>
#     </li>
#     </ul>
# </div>
#
# <hr>

# %% [markdown]
# <div >
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Vector Representation</h3>
# </div>

# %% [markdown]
# <div >
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Operations</h3>
# </div>
#
# - Scalar
# - Airthmetic
# - Dot Product
# - Distance b/w 2 vectors
# - distance compare np.linalg.norm(diff)
# - magnitude
# - unitVector = a/magnitude of a
# - Rotation
# - scaling
# - Translate

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved</i></h5>
# </div>
