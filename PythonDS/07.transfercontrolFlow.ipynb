# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">Control Flow Statement
# </h2>
#
# <div style="display:flex ; justify-content: center">
# <img src="https://pynative.com/wp-content/uploads/2021/03/python-flow-control-statements.png">
#
# </div>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px ">
#     <ul style="display: flex; flex-direction: column; gap: 10px">
#     <li>
#     <a href="#control">Conditional Statement</a>
#     </li>
#     <li>
#     <a href="#loop">
#     Loop</a>
#     </li>
#     <li>
#     <a href="#transfer">Transfer</a>
#     </li>
#
#
# </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# <div id="transfer">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">Transfer Statement</h3>
#
# <div style="display:flex ; justify-content: center">
# <img src="https://media1.giphy.com/media/v1.Y2lkPTZjMDliOTUyZDN2c2Z5OTJwZWxwZjZweWR6cW9qbGM5NTgyb24yN3YycnZoZ3R5dSZlcD12MV9naWZzX3NlYXJjaCZjdD1n/zOvBKUUEERdNm/giphy.gif">
#
# </div>
#
# <h5>Types of Transfer Statement</h4>
# <ul style="display: flex; flex-direction: column; gap: 10px;font-size: 18px">
#     <li> <a href="#break"> <code>break</code></a></li>
#     <li> <a href="#continue"> <code>continue</code></a></li>
#     <li> <a href="#pass"> <code>pass</code></a></li>
#
# </ul>
#     <a href="#more"> <code>More About Conditional Statement</code></a>
#
# </div>

# %% [markdown]
# <div id="break">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">break</h3>
# <p>Terminate The loop</p>
# <br/>
#
# </div>

# %% [markdown]
# <div id="continue">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">continue</h3>
# <p>Skip the iteration</p>
# <br/>
#
# </div>

# %% [markdown]
# <div id="pass">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">pass</h3>
# <p>go ahead</p>
# <br/>
#
# </div>

# %% [markdown]
# <div id="more">
#
# <h3 style="text-align:center; color:skyblue; text-decoration: underline  ; font-weight: bold">More About Conditional Statement</h3>
# <br/>
#
# <ul style="display: flex; flex-direction: column; gap: 10px;font-size: 18px">
#     <li><code>while else </code></li>
#     <li><code>for else</code></li>
#     <li><code>loop else break</code></li>
# </ul>
# </div>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
#    <h5 style="color:skyblue"><i>© All Rights Reserved</i></h5>
# </div>
