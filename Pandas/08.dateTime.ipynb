# %% [markdown]
# <p style="text-align:center">
#     <a href="https://tukkalearn.vercel.app" target="_blank">
#     <img src="https://raw.githubusercontent.com/itzDM/publicAssets/refs/heads/main/opengraph-image.png" width="250"  alt="Tukka Learn">
#     </a>
# </p>
#
# <h2 style="text-align:center">DateTime</h2>
#
# <h3>Table of Contents</h3>
# <div style="margin-top: 20px">
#     <ul>
#     <li>
#     <a href="">pd.to_datetime</a>
#     </li>
#     <li>
#     <a href="">dt.year</a>
#     </li>
#     <li>
#     <a href="">dt.month</a>
#     </li>
#     <li>
#     <a href="">dt.month_name</a>
#     </li>
#     <li>
#     <a href="">dt.day</a>
#     </li>
#     <li>
#     <a href="">dt.day_name</a>
#     </li>
#     <li>
#     <a href="">dt.hour</a>
#     </li>
#     <li>
#     <a href="">dt.minute</a>
#     </li>
#     <li>
#     <a href="">dt.second</a>
#     </li>
#     <li>
#     <a href="">dt.tz_localize</a>
#     </li>
#     <li>
#     <a href="">dt.tz_convert</a>
#     </li>
#     <li>
#     <a href="">pd.date_range</a>
#     </li>
#     <li>
#     <a href="">asfreq</a>
#     </li>
#     <li>
#     <a href="">shift</a>
#     </li>
#     </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# <hr>
# <div style="text-align:center">
#   <h3 style="color:orange">|| राम नाम सत्य है ||</h3>
#   <h4>Authour : सीता राम जी </h4>
# </div>
